# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5d146807875e9b621858d715')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-06-27</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-06-25</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>59</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>52.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.4%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.48</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
# ...
